# %% [markdown]
# # CHAPTER 37 - UNICODE AND BYTE STRINGS

# %% [markdown]
# ## STRING BASICS

# %%
ord('a')
# Out:
# 97

# %%
hex(97)
# Out:
# '0x61'

# %%
chr(97)
# Out:
# 'a'

# %%
0xC4
# Out:
# 196

# %%
chr(196)
# Out:
# 'Ä'

# %%
S = ' ni'

# %%
S.encode('ascii'), S.encode('latin1'), S.encode('utf8')
# Out:
# (b' ni', b' ni', b' ni')

# %%
S.encode('utf16'), len(S.encode('utf16')), len(S.encode('utf8'))
# Out:
# (b'\xff\xfe \x00n\x00i\x00', 8, 3)

# %%
B = b'spam'

# %%
S = 'eggs'

# %%
type(B), type(S)
# Out:
# (bytes, str)

# %%
B[1:], S[1:]
# Out:
# (b'pam', 'ggs')

# %%
list(B), list(S)
# Out:
# ([115, 112, 97, 109], ['e', 'g', 'g', 's'])

# %%
B[0]= 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-5f471a759607> in <module>
# ----> 1 B[0]= 'x'
#
# TypeError: 'bytes' object does not support item assignment

# %%
S[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-126ee69650f6> in <module>
# ----> 1 S[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %%
# bytes prefix works on single, double, triple quotes, raw
>>> B = B"""
xxxx
yyyy
"""

# %%
B
# Out:
# b'\nxxxx\nyyyy\n'

# %%
U = u'spam'

# %%
type(U)
# Out:
# str

# %%
U[0]
# Out:
# 's'

# %%
list(U)
# Out:
# ['s', 'p', 'a', 'm']

# %%
S = 'eggs'

# %%
S.encode()
# Out:
# b'eggs'

# %%
bytes(S, encoding='ascii')
# Out:
# b'eggs'

# %%
B = b'spam'B

# %%
B
# Out:
# b'spam'

# %%
B.decode()
# Out:
# 'spam'

# %%
str(B, encoding='ascii')
# Out:
# 'spam'

# %%
import sys

# %%
sys.platform
# Out:
# 'linux'

# %%
sys.getdefaultencoding()
# Out:
# 'utf-8'

# %%
bytes(S)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-571c772a7654> in <module>
# ----> 1 bytes(S)
#
# TypeError: string argument without an encoding

# %%
str(B)
# Out:
# "b'spam'"

# %%
len(str(B))
# Out:
# 7

# %% [markdown]
# ## CODING UNICODE STRINGS

# %%
ord('X')
# Out:
# 88

# %%
chr(88)
# Out:
# 'X'

# %%
S = 'XYZ'

# %%
len(S)
# Out:
# 3

# %%
[ord(c) for c in S]
# Out:
# [88, 89, 90]

# %%
S.encode('ascii')
# Out:
# b'XYZ'

# %%
S.encode('latin-1')
# Out:
# b'XYZ'

# %%
S.encode('utf-8')
# Out:
# b'XYZ'

# %%
chr(0xc4)
# Out:
# 'Ä'

# %%
chr(0xe8)
# Out:
# 'è'

# %%
S = '\xc4\xe8'

# %%
S
# Out:
# 'Äè'

# %%
S = '\u00c4\u00e8'

# %%
S
# Out:
# 'Äè'

# %%
len(S)
# Out:
# 2

# %%
S = '\U000000c4\U000000e8'

# %%
S
# Out:
# 'Äè'

# %%
len(S)
# Out:
# 2

# %%
S = '\u00c4\u00e8'

# %%
S
# Out:
# 'Äè'

# %%
len(S)
# Out:
# 2

# %%
S.encode('ascii')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-65-6bb8f4428afe> in <module>
# ----> 1 S.encode('ascii')
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 0-1: ordinal not in range(128)

# %%
S.encode('latin-1')
# Out:
# b'\xc4\xe8'

# %%
S.encode('utf-8')
# Out:
# b'\xc3\x84\xc3\xa8'

# %%
len(S.encode('latin-1'))
# Out:
# 2

# %%
len(S.encode('utf-8'))
# Out:
# 4

# %%
B = b'\xc4\xe8'

# %%
B
# Out:
# b'\xc4\xe8'

# %%
len(B)
# Out:
# 2

# %%
B.decode('latin-1')
# Out:
# 'Äè'

# %%
B = b'\xc3\x84\xc3\xa8'

# %%
len(B)
# Out:
# 4

# %%
B.decode('utf-8')
# Out:
# 'Äè'

# %%
len(B.decode('utf-8'))
# Out:
# 2

# %%
S = 'A\u00c4B\U000000e8C'

# %%
S
# Out:
# 'AÄBèC'

# %%
len(S)
# Out:
# 5

# %%
S.encode('latin-1')
# Out:
# b'A\xc4B\xe8C'

# %%
len(S.encode('latin-1'))
# Out:
# 5

# %%
S.encode('utf-8')
# Out:
# b'A\xc3\x84B\xc3\xa8C'

# %%
len(S.encode('utf-8'))
# Out:
# 7

# %%
S = 'A' + chr(0xC4) + 'B' + chr(0xE8) + 'C'

# %%
S
# Out:
# 'AÄBèC'

# %%
S.encode('cp500')
# Out:
# b'\xc1c\xc2T\xc3'

# %%
S.encode('cp850')
# Out:
# b'A\x8eB\x8aC'

# %%
S = 'spam'

# %%
S.encode('latin-1')
# Out:
# b'spam'

# %%
S.encode('utf-8')
# Out:
# b'spam'

# %%
S.encode('cp500')
# Out:
# b'\xa2\x97\x81\x94'

# %%
S.encode('cp850')
# Out:
# b'spam'

# %%
S = 'A\u00c4B\U000000e8C'

# %%
S.encode('utf-16')
# Out:
# b'\xff\xfeA\x00\xc4\x00B\x00\xe8\x00C\x00'

# %%
S
# Out:
# 'AÄBèC'

# %%
S.encode('utf-32')
# Out:
# b'\xff\xfe\x00\x00A\x00\x00\x00\xc4\x00\x00\x00B\x00\x00\x00\xe8\x00\x00\x00C\x00\x00\x00'

# %%
S = 'A\xC4B\xE8C'

# %%
S
# Out:
# 'AÄBèC'

# %%
S = 'A\u00C4B\U000000E8C'

# %%
S
# Out:
# 'AÄBèC'

# %%
B = b'A\xC4B\xE8C'

# %%
B
# Out:
# b'A\\u00C4B\\U000000E8C'

# %%
B = b'A\u00C4B\U000000E8C'

# %%
B
# Out:
# b'A\\u00C4B\\U000000E8C'

# %%
B = b'A\xC4B\xE8C'

# %%
B
# Out:
# b'A\xc4B\xe8C'

# %%
print(B)
# Out:
# b'A\xc4B\xe8C'

# %%
B.decode('latin-1')
# Out:
# 'AÄBèC'

# %%
S = 'AÄBèC'

# %%
B = b'AÄBèC'
# Out:
#   File "<ipython-input-113-796aad809d0f>", line 1
#     B = b'AÄBèC'
#                 ^
# SyntaxError: bytes can only contain ASCII literal characters.

# %%
B = b'A\xC4B\xE8C'

# %%
B
# Out:
# b'A\xc4B\xe8C'

# %%
B.decode()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-119-084547e57fa4> in <module>
# ----> 1 B.decode()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc4 in position 1: invalid continuation byte

# %%
B.decode('latin-1')
# Out:
# 'AÄBèC'

# %%
B = b'A\xc3\x84B\xc3\xa8C'

# %%
S = B.decode('utf-8')

# %%
S
# Out:
# 'AÄBèC'

# %%
T = S.encode('cp500')

# %%
T
# Out:
# b'\xc1c\xc2T\xc3'

# %%
U = T.decode('cp500')

# %%
U
# Out:
# 'AÄBèC'

# %%
U.encode()
# Out:
# b'A\xc3\x84B\xc3\xa8C'

# %%
S = 'A\xC4B\xE8C'

# %%
U = u'A\xC4B\xE8C'

# %%
S + U
# Out:
# 'AÄBèCAÄBèC'

# %%
'abc' + U
# Out:
# 'abcAÄBèC'

# %%
# Attributes in str but not bytes
set(dir('abc')) - set(dir(b'abc'))
# Out:
# {'casefold',
#  'encode',
#  'format',
#  'format_map',
#  'isdecimal',
#  'isidentifier',
#  'isnumeric',
#  'isprintable'}

# %%
# Attributes in bytes but not str
set(dir(b'abc')) - set(dir('abc'))
# Out:
# {'decode', 'fromhex', 'hex'}

# %%
B = b'spam'

# %%
B
# Out:
# b'spam'

# %%
type(B)
# Out:
# bytes

# %%
B[0]
# Out:
# 115

# %%
chr(B[0])
# Out:
# 's'

# %%
list(B)
# Out:
# [115, 112, 97, 109]

# %%
B[1:]
# Out:
# b'pam'

# %%
B[:-1]
# Out:
# b'spa'

# %%
B + b'1mn'
# Out:
# b'spam1mn'

# %% [markdown]
# ## OTHER WAYS TO MAKE BYTES OBJECTS

# %%
B = b'abc'

# %%
B
# Out:
# b'abc'

# %%
B = bytes('abc', 'ascii')

# %%
B
# Out:
# b'abc'

# %%
B = 'spam'.encode()

# %%
B
# Out:
# b'spam'

# %%
S = B.decode()

# %%
S
# Out:
# 'spam'

# %% [markdown]
# ## MISING STRING TYPES

# %%
B = b'spam'

# %%
B.replace(b'pa', b'XY')
# Out:
# b'sXYm'

# %%
B = B'spam'

# %%
B
# Out:
# b'spam'

# %%
B.replace(bystes('pa'), bytes('xy'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-a8909bf48401> in <module>
# ----> 1 B.replace(bystes('pa'), bytes('xy'))
#
# NameError: name 'bystes' is not defined

# %%
B.replace(bytes('pa', 'ascii'), bytes('xy', 'utf-8'))
# Out:
# b'sxym'

# %%
b'ab' + 'cd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-3b2e43ca11ed> in <module>
# ----> 1 b'ab' + 'cd'
#
# TypeError: can't concat str to bytes

# %%
b'ab'.decode() + 'cd'
# Out:
# 'abcd'

# %%
b'ab' + 'cd'.encode()
# Out:
# b'abcd'

# %%
b'ab' + bytes('cd', 'ascii')
# Out:
# b'abcd'

# %% [markdown]
# ## BYTEARRAYS IN ACTIONS

# %%
S = 'spam'

# %%
C = bytearray(S, 'ascii')

# %%
C
# Out:
# bytearray(b'spam')

# %%
B = b'spam'

# %%
C = bytearray(B)

# %%
C[0]
# Out:
# 115

# %%
C[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-df8f58f34991> in <module>
# ----> 1 C[0] = 'x'
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
C[0] = b'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-f64daf7b4209> in <module>
# ----> 1 C[0] = b'x'
#
# TypeError: 'bytes' object cannot be interpreted as an integer

# %%
C[0] = ord('x')

# %%
C
# Out:
# bytearray(b'xpam')

# %%
C[1] = b'Y'[0]

# %%
C
# Out:
# bytearray(b'xYam')

# %%
b'Y'[0]
# Out:
# 89

# %%
b'Y'
# Out:
# b'Y'

# %%
type(b'Y')
# Out:
# bytes

# %%
type(b'Y'[0])
# Out:
# int

# %%
# in bytes but not bytearray
set(dir(b'abc')) - set(dir(bytearray(b'abc')))
# Out:
# {'__getnewargs__'}

# %%
# in bytearray but not bytes
set(dir(bytearray(b'abc'))) - set(dir(b'abc'))
# Out:
# {'__alloc__',
#  '__delitem__',
#  '__iadd__',
#  '__imul__',
#  '__setitem__',
#  'append',
#  'clear',
#  'copy',
#  'extend',
#  'insert',
#  'pop',
#  'remove',
#  'reverse'}

# %%
C
# Out:
# bytearray(b'xYam')

# %%
C.append(b'LMN')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-856c5e4236d7> in <module>
# ----> 1 C.append(b'LMN')
#
# TypeError: 'bytes' object cannot be interpreted as an integer

# %%
C.append(ord('L'))

# %%
C
# Out:
# bytearray(b'xYamL')

# %%
C.extend(b'MNO')

# %%
C
# Out:
# bytearray(b'xYamLMNO')

# %%
C + b'!#'
# Out:
# bytearray(b'xYamLMNO!#')

# %%
C[0]
# Out:
# 120

# %%
C[1:]
# Out:
# bytearray(b'YamLMNO')

# %%
len(C)
# Out:
# 8

# %%
C.replace('xY', 'sp')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-05b3c0630bde> in <module>
# ----> 1 C.replace('xY', 'sp')
#
# TypeError: a bytes-like object is required, not 'str'

# %%
C.replace(b'xY', b'sp')
# Out:
# bytearray(b'spamLMNO')

# %%
C
# Out:
# bytearray(b'xYamLMNO')

# %%
C * 4
# Out:
# bytearray(b'xYamLMNOxYamLMNOxYamLMNOxYamLMNO')

# %%
B
# Out:
# b'spam'

# %%
list(B)
# Out:
# [115, 112, 97, 109]

# %%
C
# Out:
# bytearray(b'xYamLMNO')

# %%
list(C)
# Out:
# [120, 89, 97, 109, 76, 77, 78, 79]

# %%
S
# Out:
# 'spam'

# %%
list(S)
# Out:
# ['s', 'p', 'a', 'm']

# %% [markdown]
# ## USING TEXT AND BINARY FILES

# %%
file = open('files/temp', )

# %%
size = file.write('abxc\n')

# %%
file.close()

# %%
file = open('files/temp')

# %%
text = file.read()

# %%
text
# Out:
# 'abxc\n'

# %%
open('files/temp', 'w').write('abd\n') # Write in text mode: adds \r
# Out:
# 4

# %%
open('files/temp', 'r').read() # Read in text mode: drops \r
# Out:
# 'abd\n'

# %%
open('files/temp', 'rb').read() # Read in binary mode: verbatim
# Out:
# b'abd\n'

# %%
open('files/temp', 'wb').write('abc\n') # Write in binary mode
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-853dea4ef3c1> in <module>
# ----> 1 open('files/temp', 'wb').write('abc\n') # Write in binary mode
#
# TypeError: a bytes-like object is required, not 'str'

# %%
open('files/temp', 'wb').write(b'abc\n') # Binary mode output, provide a bytes
# Out:
# 4

# %%
open('files/temp', 'r').read() # Text mode input, returns a str
# Out:
# 'abc\n'

# %%
open('files/temp', 'rb').read() # Binary mode input, returns a bytes
# Out:
# b'abc\n'

# %%
open('files/temp', 'wb').write(b'a\x00c')
# Out:
# 3

# %%
open('files/temp', 'r').read()
# Out:
# 'a\x00c'

# %%
open('files/temp', 'rb').read()
# Out:
# b'a\x00c'

# %% [markdown]
# ## USING UNICODE FILES

# %%
S = 'A\xc4B\xe8C'

# %%
S
# Out:
# 'AÄBèC'

# %%
len(S)
# Out:
# 5

# %%
L = S.encode('latin-1')

# %%
L
# Out:
# b'A\xc4B\xe8C'

# %%
len(L)
# Out:
# 5

# %%
U = S.encode('utf-8')

# %%
len(U)
# Out:
# 7

# %%
open('files/latindata', 'w', encoding='latin-1').write(S)
# Out:
# 5

# %%
open('files/utf8data', 'w', encoding='utf-8').write(S)
# Out:
# 5

# %%
open('files/latindata', 'rb').read()
# Out:
# b'A\xc4B\xe8C'

# %%
open('files/utf8data', 'rb').read()
# Out:
# b'A\xc3\x84B\xc3\xa8C'

# %%
open('files/latindata', 'r', encoding='latin-1').read()
# Out:
# 'AÄBèC'

# %%
open('files/utf8data', 'r', encoding='utf-8').read()
# Out:
# 'AÄBèC'

# %%
X = open('files/latindata', 'rb').read()

# %%
X.decode('latin-1')
# Out:
# 'AÄBèC'

# %%
X = open('files/utf8data', 'rb').read()

# %%
X.decode()
# Out:
# 'AÄBèC'

# %%
X
# Out:
# b'A\xc3\x84B\xc3\xa8C'

# %% [markdown]
# ## UNICODE FILENAMES AND STREAMS

# %%
import sys

# %%
sys.getdefaultencoding(), sys.getfilesystemencoding()
# Out:
# ('utf-8', 'utf-8')

# %%
f = open('files/xxx\u00A5', 'w')

# %%
f.write('\xA5999\n')
# Out:
# 5

# %%
f.close()

# %%
print(open('files/xxx\u00A5').read())
# Out:
# ¥999

# %%
import glob

# %%
glob.glob('files/*\u00A5*')
# Out:
# ['files/xxx¥']

# %%
glob.glob('files/b"*\u00A5*"')
# Out:
# []

# %% [markdown]
# ## THE re PATTERN-MATCHING MODULE

# %%
import re

# %%
S = 'Bugger all down here on earth!'

# %%
B = b'Bugger all down here on earth!'

# %%
re.match('(.*) down (.*) on (.*)' ,S).groups()
# Out:
# ('Bugger all', 'here', 'earth!')

# %%
re.match(b'(.*) down (.*) on (.*)' ,B).groups()
# Out:
# (b'Bugger all', b'here', b'earth!')

# %% [markdown]
# ## THE STRUCT BINARY DATA MODULE

# %%
from struct import pack

# %%
pack('>i4sh', 7, b'spam', 8)
# Out:
# b'\x00\x00\x00\x07spam\x00\x08'

# %%
import struct

# %%
B = struct.pack('>i4sh', 7, b'spam', 8)

# %%
B
# Out:
# b'\x00\x00\x00\x07spam\x00\x08'

# %%
vals = struct.unpack('>i4sh', B)

# %%
vals
# Out:
# (7, b'spam', 8)

# %%
vals = struct.unpack('>i4sh', B.decode())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-d4d22a5db21c> in <module>
# ----> 1 vals = struct.unpack('>i4sh', B.decode())
#
# TypeError: a bytes-like object is required, not 'str'

# %%
F = open('files/data.bin', 'wb')

# %%
data = struct.pack('>i4sh', 7, b'spam', 8)

# %%
F.write(data)
# Out:
# 10

# %%
F.close()

# %%
F = open('files/data.bin', 'rb')

# %%
data = F.read()

# %%
data
# Out:
# b'\x00\x00\x00\x07spam\x00\x08'

# %%
values = struct.unpack('>i4sh', data)

# %%
values
# Out:
# (7, b'spam', 8)

# %%
values
# Out:
# (7, b'spam', 8)

# %%
bin(values[0])
# Out:
# '0b111'

# %%
values[0] & 0x01
# Out:
# 1

# %%
values[0] | 0b1010
# Out:
# 15

# %%
bin(values[0] | 0b1010)
# Out:
# '0b1111'

# %%
bin(values[0] ^ 0b1010)
# Out:
# '0b1101'

# %%
bool(values[0] & 0b100)
# Out:
# True

# %%
bool(values[0] & 0b1000)
# Out:
# False

# %%
values[1]
# Out:
# b'spam'

# %%
values[1][0]
# Out:
# 115

# %%
values[1][1:]
# Out:
# b'pam'

# %%
bin(values[1][0])
# Out:
# '0b1110011'

# %%
bin(values[1][0] | 0b1100)
# Out:
# '0b1111111'

# %%
values[1][0] | 0b1100
# Out:
# 127

# %% [markdown]
# ## THE PICKLE OBJECT SERIALIZATION MODULUE

# %%
import pickle

# %%
pickle.dumps([1, 2, 3])
# Out:
# b'\x80\x04\x95\x0b\x00\x00\x00\x00\x00\x00\x00]\x94(K\x01K\x02K\x03e.'

# %%
pickle.dumps([1, 2, 3], protocol=0)
# Out:
# b'(lp0\nI1\naI2\naI3\na.'

# %%
pickle.dump([1, 2, 3], open('files/temp', 'w'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-312a429c42b9> in <module>
# ----> 1 pickle.dump([1, 2, 3], open('files/temp', 'w'))
#
# TypeError: write() argument must be str, not bytes

# %%
pickle.dump([1, 2, 3], open('files/temp', 'w'), protocol=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-212-eae232ad0c71> in <module>
# ----> 1 pickle.dump([1, 2, 3], open('files/temp', 'w'), protocol=0)
#
# TypeError: write() argument must be str, not bytes

# %%
pickle.dump([1, 2, 3], open('files/temp', 'wb'))

# %%
open('files/temp', 'r').read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-215-27b0e3162e1b> in <module>
# ----> 1 open('files/temp', 'r').read()
#
# /usr/lib64/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %%
pickle.dump([1, 2, 3], open('files/temp', 'wb'))

# %%
pickle.load(open('files/temp', 'rb'))
# Out:
# [1, 2, 3]

# %%
open('files/temp', 'rb').read()
# Out:
# b'\x80\x04\x95\x0b\x00\x00\x00\x00\x00\x00\x00]\x94(K\x01K\x02K\x03e.'

# %% [markdown]
# ## XML PARSING TOOLS

# %%
import re

# %%
text = open('files/mybooks.xml').read()

# %%
found = re.findall('<title>(.*)</title>', text)

# %%
found
# Out:
# ['Learning Python', 'Programming Python', 'Python Pocket Reference']

# %%
from xml.dom.minidom import parse, Node

# %%
xmltree = parse('files/mybooks.xml')

# %%
for node1 in xmltree.getElementsByTagName('title'):
    for node2 in node1.childNodes:
        if node2.nodeType == Node.TEXT_NODE:
            print(node2.data)
# Out:
# Learning Python
# Programming Python
# Python Pocket Reference

# %%
import xml.sax.handler
