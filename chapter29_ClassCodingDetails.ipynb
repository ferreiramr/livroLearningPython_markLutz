# %% [markdown]
# # CHAPTER 29 - CLASS CODING DETAILS

# %%
class SharedData:
    spam = 42

# %%
x = SharedData()

# %%
y = SharedData()

# %%
x.spam, y.spam
# Out:
# (42, 42)

# %%
SharedData.spam = 99

# %%
x.spam, y.spam, SharedData.spam
# Out:
# (99, 99, 99)

# %%
x.spam = 88

# %%
x.spam, y.spam, SharedData.spam
# Out:
# (88, 99, 99)

# %%
class MixedNames:
    data = 'spam'
    def __init__(self, value):
        self.data = value
    def display(self):
        print(self.data, MixedNames.data)

# %%
x = MixedNames(1)

# %%
y = MixedNames(2)

# %%
x.display(); y.display()
# Out:
# 1 spam
# 2 spam

# %%
class NextClass:
    def printer(self, text):
        self.message = text
        print(self.message)

# %%
x = NextClass()

# %%
x.printer('instance call')
# Out:
# instance call

# %%
x.message
# Out:
# 'instance call'

# %%
NextClass.printer(x, 'class call')
# Out:
# class call

# %%
x.message
# Out:
# 'class call'

# %%
class Super:
    def method(self):
        print('in Super.method')

# %%
class Sub(Super):
    def method(self):
        print('starting Sub.method')
        Super.method(self)
        print('ending Sub.method')

# %%
x = Super()

# %%
x.method()
# Out:
# in Super.method

# %%
x = Sub()

# %%
x.method()
# Out:
# starting Sub.method
# in Super.method
# ending Sub.method

# %%
class Super:
    def method(self):
        print('in Super.method')
    def delegate(self):
        self.action()

# %%
class Inheritor(Super):
    pass

# %%
class Replacer(Super):
    def method(self):
        print('in Replacer.method')

# %%
class Extender(Super):
    def method(self):
        print('starint Externder.method')
        Super.method(self)
        print('ending Extender.method')

# %%
class Provider(Super):
    def action(self):
        print('in Provider.action')

# %%
for klass in (Inheritor, Replacer, Extender):
    print(f"\n + {klass.__name__} + '...'")
    klass().method()
print("\nProvider...")
x = Provider()
x.delegate()
# Out:
#  + Inheritor + '...'
# in Super.method
#
#  + Replacer + '...'
# in Replacer.method
#
#  + Extender + '...'
# starint Externder.method
# in Super.method
# ending Extender.method
#
# Provider...
# in Provider.action

# %%
class Super:
    def delegate(self):
        self.action()
    def action(self):
        assert False, 'action must be defined!'

# %%
X = Super()

# %%
X.delegate()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-43-028eeaa7d4f1> in <module>
# ----> 1 X.delegate()
#
# <ipython-input-41-b272d3f715fe> in delegate(self)
#       1 class Super:
#       2     def delegate(self):
# ----> 3         self.action()
#       4     def action(self):
#       5         assert False, 'action must be defined!'
#
# <ipython-input-41-b272d3f715fe> in action(self)
#       3         self.action()
#       4     def action(self):
# ----> 5         assert False, 'action must be defined!'
#
# AssertionError: action must be defined!

# %%
class Super:
    def delegate(self):
        self.action()
    def action(self):
        raise NotImplementedError('action must be defined!')

# %%
X = Super()

# %%
X.delegate()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-50-028eeaa7d4f1> in <module>
# ----> 1 X.delegate()
#
# <ipython-input-48-08eb6b1ce73f> in delegate(self)
#       1 class Super:
#       2     def delegate(self):
# ----> 3         self.action()
#       4     def action(self):
#       5         raise NotImplementedError('action must be defined!')
#
# <ipython-input-48-08eb6b1ce73f> in action(self)
#       3         self.action()
#       4     def action(self):
# ----> 5         raise NotImplementedError('action must be defined!')
#
# NotImplementedError: action must be defined!

# %%
from abc import ABCMeta, abstractmethod

# %%
class Super(metaclass=ABCMeta):
    def delegate(self):
        self.action()
    @abstractmethod
    def action(self):
        pass

# %%
X = Super()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ea1510062678> in <module>
# ----> 1 X = Super()
#
# TypeError: Can't instantiate abstract class Super with abstract methods action

# %%
class Sub(Super):
    pass

# %%
X = Sub()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-22fb2fa1eb83> in <module>
# ----> 1 X = Sub()
#
# TypeError: Can't instantiate abstract class Sub with abstract methods action

# %%
class Sub(Super):
    def action(self):
        print('spam')

# %%
X = Sub()

# %%
X.delegate()
# Out:
# spam
