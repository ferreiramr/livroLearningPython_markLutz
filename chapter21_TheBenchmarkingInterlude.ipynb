# %% [markdown]
# ## CHAPTER 21 - THE BENCHMARKING INTERLUDE

# %%
# %%time
pow(2, 1000)
# Out:
# Wall time: 0 ns
# 

# %%
# %timeit pow(2, 1000)
# Out:
# 944 ns ± 11.8 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
reps = 10000

# %%
repslist = list(range(reps))

# %%
# %%timeit
res = []
for x in repslist:
    res.append(abs(x))
# Out:
# 1.01 ms ± 30.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit 
res = [abs(x) for x in repslist]
# Out:
# 459 µs ± 19.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
res = list(abs(x) for x in repslist)
# Out:
# 722 µs ± 95.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
res = list(map(abs, repslist))
# Out:
# 170 µs ± 4.71 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
