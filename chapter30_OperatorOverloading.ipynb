# %% [markdown]
# # CHAPTER 30 - OPERATOR OVERLOADING

# %% [markdown]
# ## The Basics

# %%
class Number:
    def __init__(self, start):
        self.data = start
    def __sub__(self, other):
        return Number(self.data - other)

# %%
X = Number(5)

# %%
X

# %%
Y = X - 2

# %%
Y.data
# Out:
# 3

# %%
X.data
# Out:
# 5

# %%
class Indexer:
    def __getitem__(self, index):
        return index ** 2

# %%
X = Indexer()

# %%
X[2]
# Out:
# 4

# %%
for i in range(5):
    print(X[i], end=' ')
# Out:
# 0 1 4 9 16

# %%
L = [5, 6, 7, 8, 9]

# %%
L[2:4]
# Out:
# [7, 8]

# %%
L[1:]
# Out:
# [6, 7, 8, 9]

# %%
L[:-1]
# Out:
# [5, 6, 7, 8]

# %%
L[::2]
# Out:
# [5, 7, 9]

# %%
L[slice(2, 4)]
# Out:
# [7, 8]

# %%
L[slice(1, None)]
# Out:
# [6, 7, 8, 9]

# %%
L[slice(1, None)]
# Out:
# [6, 7, 8, 9]

# %%
L[slice(None, -1)]
# Out:
# [5, 6, 7, 8]

# %%
L[slice(None, None, 2)]
# Out:
# [5, 7, 9]

# %%
class Indexer:
    data = [5, 6, 7, 8, 9]
    def __getitem__(self, index):
        print('getitem:', index)
        return self.data[index]

# %%
X = Indexer()

# %%
X[0]
# Out:
# getitem: 0
# 5

# %%
X[1]
# Out:
# getitem: 1
# 6

# %%
X[-1]
# Out:
# getitem: -1
# 9

# %%
X[2:4]
# Out:
# getitem: slice(2, 4, None)
# [7, 8]

# %%
X[1:]
# Out:
# getitem: slice(1, None, None)
# [6, 7, 8, 9]

# %%
X[:-1]
# Out:
# getitem: slice(None, -1, None)
# [5, 6, 7, 8]

# %%
X[::2]
# Out:
# getitem: slice(None, None, 2)
# [5, 7, 9]

# %%
class Indexer:
    def __getitem__(self, index):
        if isinstance(index, int):
            print('indexing', int)
        else:
            print('slicing', index.start, index.stop, index.step)

# %%
X = Indexer()

# %%
X[99]
# Out:
# indexing <class 'int'>

# %%
X[1:99:2]
# Out:
# slicing 1 99 2

# %%
X[1:]
# Out:
# slicing 1 None None

# %%
class StepperIndex:
    def __getitem__(self, i):
        return self.data[i]

# %%
X = StepperIndex()

# %%
X.data = "Spam"

# %%
X[1]
# Out:
# 'p'

# %%
for item in X:
    print(item, end=' ')
# Out:
# S p a m

# %%
'p' in X
# Out:
# True

# %%
[c for c in X]
# Out:
# ['S', 'p', 'a', 'm']

# %%
list(map(str.upper, X))
# Out:
# ['S', 'P', 'A', 'M']

# %%
a, b, c, d = X

# %%
a, b, c, d
# Out:
# ('S', 'p', 'a', 'm')

# %%
list(X), tuple(X), ''.join(X)
# Out:
# (['S', 'p', 'a', 'm'], ('S', 'p', 'a', 'm'), 'Spam')

# %%
X

# %%
class Squares:
    def __init__(self, start, stop):
        self.value = start - 1
        self.stop = stop
    def __iter__(self):
        return self
    def __next__(self):
        if self.value == self.stop:
            raise StopIteration
        self.value += 1
        return self.value ** 2

# %%
for i in Squares(1, 5):
    print(i, end=' ')
# Out:
# 1 4 9 16 25

# %%
list(Squares(1, 5))
# Out:
# [1, 4, 9, 16, 25]

# %%
X = Squares(1, 5)

# %%
I = iter(X)

# %%
next(I)
# Out:
# 1

# %%
next(I)
# Out:
# 4

# %%
next(I)
# Out:
# 9

# %%
next(I)
# Out:
# 16

# %%
next(I)
# Out:
# 25

# %%
next(I)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-59-ebc5a6f5e444> in <module>
# ----> 1 next(I)
#
# <ipython-input-49-f3368d3a08b1> in __next__(self)
#       7     def __next__(self):
#       8         if self.value == self.stop:
# ----> 9             raise StopIteration
#      10         self.value += 1
#      11         return self.value ** 2
#
# StopIteration:

# %%
X = Squares(1, 5)

# %%
list(X)
# Out:
# [1, 4, 9, 16, 25]

# %%
list(X)
# Out:
# []

# %%
36 in Squares(1, 10)
# Out:
# True

# %%
a, b, c = Squares(1, 3)

# %%
a, b, c
# Out:
# (1, 4, 9)

# %%
':'.join(map(str, Squares(1, 5)))
# Out:
# '1:4:9:16:25'

# %%
X = Squares(1, 5)

# %%
tuple(X), tuple(X)
# Out:
# ((1, 4, 9, 16, 25), ())

# %%
X = list(Squares(1, 5))

# %%
tuple(X), tuple(X)
# Out:
# ((1, 4, 9, 16, 25), (1, 4, 9, 16, 25))

# %%
def gsquares(start, stop):
    for i in range(start, stop + 1):
        yield i ** 2

# %%
list(gsquares(1, 5))
# Out:
# [1, 4, 9, 16, 25]

# %%
S = 'ace'

# %%
for x in S:
    for y in S:
        print(x + y, end=' ')
# Out:
# aa ac ae ca cc ce ea ec ee

# %%
def gen(x):
    for i in range(x): yield i ** 2

# %%
G = gen(5)

# %%
G.__iter__() == G
# Out:
# True

# %%
I = iter(G)

# %%
next(I), next(I)
# Out:
# (0, 1)

# %%
list(gen(5))
# Out:
# [0, 1, 4, 9, 16]

# %%
class Squares:
    def __init__(self, start, stop):
        self.start = start
        self.stop = stop
    def __iter__(self):
        for value in range(self.start, self.stop + 1):
            yield value ** 2

# %%
for i in Squares(1, 5):
    print(i, end=' ')
# Out:
# 1 4 9 16 25

# %%
S = Squares(1, 5)

# %%
S

# %%
I = iter(S)

# %%
I
# Out:
# <generator object Squares.__iter__ at 0x0000012B299D7580>

# %%
next(I)
# Out:
# 1

# %%
next(I)
# Out:
# 4

# %%
next(I)
# Out:
# 9

# %%
next(I)
# Out:
# 16

# %%
next(I)
# Out:
# 25

# %%
next(I)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-22-ebc5a6f5e444> in <module>
# ----> 1 next(I)
#
# StopIteration:

# %%
S = Squares(1, 5)

# %%
I = iter(S)

# %%
next(I), next(I)
# Out:
# (1, 4)

# %%
J = iter(S)

# %%
next(J)
# Out:
# 1

# %%
next(I)
# Out:
# 9

# %%
S

# %%
print(S)
# Out:
# <__main__.Squares object at 0x0000012B294E02E0>

# %%
list(S)
# Out:
# [1, 4, 9, 16, 25]

# %%
S = Squares(1, 3)

# %%
for i in S:
    for j in S:
        print(f'{i}:{j}', end=' ')
# Out:
# 1:1 1:4 1:9 4:1 4:4 4:9 9:1 9:4 9:9

# %%
class Squares:
    def __init__(self, start, stop):
        self.start = start
        self.stop = stop
    def __iter__(self):
        return SquaresIter(self.start, self.stop)

class SquaresIter:
    def __init__(self, start, stop):
        self.value = start - 1
        self.stop = stop
    def __next__(self):
        if self.value == self.stop:
            raise StopIteration
        self.value += 1
        return self.value ** 2

# %%
for i in Squares(1, 5):
    print(i, end=' ')
# Out:
# 1 4 9 16 25

# %%
S = Squares(1, 5)

# %%
I = iter(S)

# %%
next(I), next(I)
# Out:
# (1, 4)

# %%
J = iter(S)

# %%
next(J)
# Out:
# 1

# %%
next(I)
# Out:
# 9

# %%
S = Squares(1, 3)

# %%
for i in S:
    for j in S:
        print(f'{i}:{j}', end=' ')
# Out:
# 1:1 1:4 1:9 4:1 4:4 4:9 9:1 9:4 9:9

# %%
class SkipObject:
    def __init__(self, wrapped):
        self.wrapped = wrapped
    def __iter__(self):
        offset = 0
        while offset < len(self.wrapped):
            item = self.wrapped[offset]
            offset += 2
            yield item

# %%
skipper = SkipObject('abcdef')

# %%
I = iter(skipper)

# %%
next(I)
# Out:
# 'a'

# %%
next(I)
# Out:
# 'c'

# %%
next(I)
# Out:
# 'e'

# %%
for x in skipper:
    for y in skipper:
        print(x + y, end=' ')
# Out:
# aa ac ae ca cc ce ea ec ee

# %%
class Empty:
    def __getattr__(self, attrname):
        if attrname == 'age':
            return 40
        else:
            raise AttributeError(attrname)

# %%
X = Empty()

# %%
X.age
# Out:
# 40

# %%
X.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-94c5350c32f8> in <module>
# ----> 1 X.name
#
# <ipython-input-92-3f5744b9e440> in __getattr__(self, attrname)
#       4             return 40
#       5         else:
# ----> 6             raise AttributeError(attrname)
#
# AttributeError: name

# %%
class Accesscontrol:
    def __setattr__(self, attr, value):
        if attr == 'age':
            self.__dict__[attr] = value + 10
        else:
            raise AttributeError(attr + ' not allowed')

# %%
X = Accesscontrol()

# %%
X.age = 40

# %%
X.age
# Out:
# 50

# %%
X.name = 'Bob'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-05b099f59059> in <module>
# ----> 1 X.name = 'Bob'
#
# <ipython-input-102-dfed6456616c> in __setattr__(self, attr, value)
#       4             self.__dict__[attr] = value + 10
#       5         else:
# ----> 6             raise AttributeError(attr + ' not allowed')
#
# AttributeError: name not allowed

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-ae1b2ccea957> in <module>
# ----> 1 self.age = value + 10
#
# NameError: name 'value' is not defined

# %% [markdown]
# ## Emulating Privacy for Instance Attributes: Part 1

# %%
class PrivateExc(Exception):
    pass

# %%
class Privacy:
    def __setattr__(self, attrname, value):
        if attrname in self.privates:
            raisePrivateExc(attrname, self)
        else:
            self.__dict__[attrname] = value

# %%
class Test1(Privacy):
    privates =  ['age']

# %%
class Test2(Privacy):
    privates = ['name', 'pay']
    
    def __init__(self):
        self.__dict__['name'] = 'Tom'

# %%
 x = Test1()

# %%
y = Test2()

# %%
x.name = 'Bob'

# %%
y.name = 'Sue'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-5241bd7fed48> in <module>
# ----> 1 y.name = 'Sue'
#
# <ipython-input-23-a3be87c0958e> in __setattr__(self, attrname, value)
#       2     def __setattr__(self, attrname, value):
#       3         if attrname in self.privates:
# ----> 4             raisePrivateExc(attrname, self)
#       5         else:
#       6             self.__dict__[attrname] = value
#
# NameError: name 'raisePrivateExc' is not defined

# %%
print(x.name, y.name)
# Out:
# Bob Tom

# %%
x.age = 30
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c2c6178ecba3> in <module>
# ----> 1 x.age = 30
#
# <ipython-input-23-a3be87c0958e> in __setattr__(self, attrname, value)
#       2     def __setattr__(self, attrname, value):
#       3         if attrname in self.privates:
# ----> 4             raisePrivateExc(attrname, self)
#       5         else:
#       6             self.__dict__[attrname] = value
#
# NameError: name 'raisePrivateExc' is not defined

# %%
y.age = 40

# %%
print(x.age, y.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b4f9a0a9cb89> in <module>
# ----> 1 print(x.age, y.age)
#
# AttributeError: 'Test1' object has no attribute 'age'

# %% [markdown]
# ## String Representation: \__repr\__ and \__str__

# %%
class adder:
    def __init__(self, value=0):
        self.data = value

    def __add__(self, other):
        self.data += other

# %%
x = adder()

# %%
print(x)
# Out:
# <__main__.adder object at 0x7f70550105e0>

# %%
x

# %%
class addrepr(adder):
    def __repr__(self):
        return f'addrepr({self.data})'

# %%
x = addrepr(2)

# %%
x + 1

# %%
x
# Out:
# addrepr(3)

# %%
print(x)
# Out:
# addrepr(3)

# %%
str(x), repr(x)
# Out:
# ('addrepr(3)', 'addrepr(3)')

# %%
class addstr(adder):
    def __str__(self):
        return f'[Value: {self.data}]'

# %%
x = addstr(3)

# %%
x + 1

# %%
x

# %%
print(x)
# Out:
# [Value: 4]

# %%
class addboth(adder):
    def __str__(self):
        return f'[Value: {self.data}]'
    
    def __repr__(self):
        return f'addboth({self.data})'

# %%
x = addboth(4)

# %%
x + 1

# %%
print(x)
# Out:
# [Value: 5]

# %%
str(x), repr(x)
# Out:
# ('[Value: 5]', 'addboth(5)')

# %% [markdown]
# ### Display Usage Notes

# %%
class Printer:
    def __init__ (self, val):
        self.val = val

    def __str__(self):
        return str(self.val)

# %%
objs = [Printer(2), Printer(3)]

# %%
for x in objs: 
    print(x)
# Out:
# 2
# 3

# %%
print(objs)
# Out:
# [<__main__.Printer object at 0x7f7054e88eb0>, <__main__.Printer object at 0x7f7047b55a30>]

# %%
objs
# Out:
# [<__main__.Printer at 0x7f7054e88eb0>, <__main__.Printer at 0x7f7047b55a30>]

# %%
class Printer:
    def __init__(self, val):
        self.val = val

    def __repr__(self):
        return str(self.val)

# %%
objs = [Printer(2), Printer(3)]

# %%
for x in objs:
    print(x)
# Out:
# 2
# 3

# %%
print(objs)
# Out:
# [2, 3]

# %%
objs
# Out:
# [2, 3]

# %% [markdown]
# ## Right-Side and In-Place Uses: \__radd\__ and \__iadd\__

# %% [markdown]
# ## Right-Side Addition

# %%
class Adder:
    def __init__(self, value=0):
        self.data = value

    def __add__(self, other):
        return self.data + other

# %%
x = Adder(5)

# %%
x + 2
# Out:
# 7

# %%
2 + x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-4f4e32a7ea51> in <module>
# ----> 1 2 + x
#
# TypeError: unsupported operand type(s) for +: 'int' and 'Adder'

# %%
class Comuter1:
    def __init__(self, val):
        self.val = val

    def __add__(self, other):
        print('add', self.val, other)
        return self.val + other

    def __radd__(self, other):
        print('add', self.val, other)
        return other + self.val

# %%
x = Comuter1(88)

# %%
y = Comuter1(99)

# %%
x + 1
# Out:
# add 88 1
# 89

# %%
1 + y
# Out:
# add 99 1
# 100

# %%
x + y
# Out:
# add 88 <__main__.Comuter1 object at 0x7f7055303550>
# add 99 88
# 187

# %% [markdown]
# ### Reusing \__add\__ in \__radd\__

# %%
class Commuter2:
    def __init__(self, val):
        self.val = val

    def __add__(self, other):
        print('add', self.val, other)
        return self.val + other

    def __radd__(self, other):
        return self.__add__(other)

# %%
class Commuter3:
    def __init__(self, val):
        self.val = val

    def __add__(self, other):
        print('add', self.val, other)
        return self.val + other

    def __radd__(self, other):
        return self + other

# %%
class Commuter4:
    def __init__(self, val):
        self.val = val

    def __add__(self, other):
        print('add', self.val, other)
        return self.val + other

    __radd__ = __add__

# %%
x = Commuter4(4)

# %%
y = Commuter4(1)

# %%
x + y
# Out:
# add 4 <__main__.Commuter4 object at 0x7fa698ec35b0>
# add 1 4
# 5

# %% [markdown]
# ### Propagating class type

# %%
class Commuter5:

    def __init__(self, val):
        self.val = val

    def __add__(self, other):
        if isinstance(other, Commuter5):
            other = other.val
        return Commuter5(self.val + other)

    def __radd__(self, other):
        return Commuter5(other + self.val)

    def __str__(self):
        return f'<Commuter5: {self.val}'

# %%
x = Commuter5(88)

# %%
y = Commuter5(99)

# %%
print(x + 10)
# Out:
# <Commuter5: 98

# %%
print(10 + y)
# Out:
# <Commuter5: 109

# %%
z = x + y

# %%
print(z)
# Out:
# <Commuter5: 187

# %%
print(z + 10)
# Out:
# <Commuter5: 197

# %%
print(z + z)
# Out:
# <Commuter5: 374

# %%
print(z + z + 1)
# Out:
# <Commuter5: 375

# %%
z = x + y

# %%
print(z)
# Out:
# <Commuter5: 187

# %%
print(z + 10)
# Out:
# <Commuter5: 197

# %%
print(z + z)
# Out:
# <Commuter5: 374

# %%
print(z + z + 1)
# Out:
# <Commuter5: 375

# %% [markdown]
# ### Call Expressions: \__call\__

# %%
class Calee:
    def __call__(self, *pargs, **kargs):
        print(f'Called:, {pargs}, {kargs}')

# %%
C = Calee()

# %%
C(1, 2, 3)
# Out:
# Called:, (1, 2, 3), {}

# %%
C(1, 2, 3, x=4, y=5)
# Out:
# Called:, (1, 2, 3), {'x': 4, 'y': 5}

# %%
class Prod:
    def __init__(self, value):
        self.value = value
    
    def __call__(self, other):
        return self.value * other

# %%
x = Prod(2)

# %%
x(3)
# Out:
# 6

# %%
x(4)
# Out:
# 8

# %%
class Prod:
    def __init__(self, value):
        self.value = value

    def comp(self, other):
        return self.value * other

# %%
x = Prod(3)

# %%
x.comp(3)
# Out:
# 9

# %%
x.comp(4)
# Out:
# 12
