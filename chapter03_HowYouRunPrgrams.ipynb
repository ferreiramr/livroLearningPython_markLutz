# %% [markdown]
# # CHAPTER 03 - HOW YOU RUN PROGRAMS

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
lumberjack = 'okay'

# %%
lumberjack
# Out:
# 'okay'

# %%
2 ** 8
# Out:
# 256

# %%
'Span!' * 8
# Out:
# 'Span!Span!Span!Span!Span!Span!Span!Span!'

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Professor\\Documents\\livroLearningPython_MarkLutz'

# %%
for x in 'spam':
    print(x)
# Out:
# s
# p
# a
# m

# %%
for x in 'spam':
    print(x)
print('done')
# Out:
# s
# p
# a
# m
# done

# %%
import sys

# %%
print(sys.platform)
# Out:
# win32

# %%
print(2 ** 100)
# Out:
# 1267650600228229401496703205376

# %%
x = 'Spam!'

# %%
print(x * 8)
# Out:
# Spam!Spam!Spam!Spam!Spam!Spam!Spam!Spam!
